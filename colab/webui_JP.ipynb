# %%
# @title インストール
# !pip install stream-translator-gpt[webui]

# %%
# @title 実行
# @markdown 起動後、下に出力される `https://xxxxx.gradio.live` リンクをクリックして WebUI を開きます。
# !stream-translator-gpt-webui --share
